# %%
import pathlib
import shutil

# %%
datasets = [
    "concrete_strength",
    "rainfall", 
    "wine_quality",
    "employee_attrition",
    "blueberry_yield",
    "heat_flux",
    "abalone",
    "mohs_hardness", 
    "crab_age",
    "housing_price_california",
    "influencer",
    "cirrhosis_outcomes",
    "sticker_sales",
    "reservation_cancellation",
    "obesity_risk",
    "loan_approval",
    "calorie_expenditure",
    "credit_fusion",
    "bank_churn",
    "failure",
    "unknown_a",
    "horse_survival", 
    "media_cost",
    "smoking",
    "mercedes_testing_time",
    "insurance_claim",
    "synthanic",
    "mental_health",
    "flood_probability",
    "insurance_premium",
    "covertype",
    "loan_loss",
]

# %%
def get_base_paths(data_name, versions_list):
    kaggle_name = f"kaggle_{data_name}"
    base_path = pathlib.Path("../openfe_experiments")

    paths = [base_path / f"openfe_{kaggle_name}_10k_mcf_2_db_fb_False_grid_search_{version}" / kaggle_name for version in versions_list]
    return paths

# %%
import os
import re

import matplotlib.pyplot as plt

from rampds.fe_utils.utils import FileUtils


# TODO: add these in a class / UPPERCASE if use them as constants / put them in other shared utils dir
EXPE_META_DATA_FILE = "experiment_metadata.json"
SCORES_FILE = "scores.csv"
SCORES_PLOT_FILE = "openfe_scores_plot.png"


def score_is_better(score, comparison_score, objective_direction):
    """ Check if the current score is better than the best score based on the objective direction.

    Args:
        score (float): The current score to evaluate.
        comparison_score (float): The score to compare against.
        objective_direction (str): The direction of the objective, either 'minimize' or 'maximize'.

    Returns:
        _type_: _description_
    """
    if objective_direction == "minimize":
        return score < comparison_score
    else:
        return score > comparison_score


class OpenFEUtils:
    """
    Utility class for OpenFE related operations.
    """

    @staticmethod
    def get_experiment_type(min_cand_feat, data_blocks, feature_boost, selection_method):
        """
        Constructs a string representing the experiment type based on parameters.

        Parameters:
            min_cand_feat (int): Minimum candidate features.
            data_blocks (int): Number of data blocks.
            feature_boost (str): Feature boost method.
            selection_method (str): Feature selection method.

        Returns:
            str: Formatted experiment type string.
        """
        return f"{min_cand_feat//1000}k_mcf_{data_blocks}_db_fb_{feature_boost}_{selection_method}"
    
    @staticmethod
    def plot_and_save_scores(
        n_feat, 
        scores, 
        original_score, 
        score_name, 
        data_name, 
        objective_direction, 
        results_dir,
        save_plot=True,
        experiment_label=None,
        best_n_selected_features=None,
        ):
        """
        Plots the scores and saves the visualization to a file.

        Parameters:
            n_feat (list): Number of selected features.
            scores (list): Mean scores corresponding to the selected features.
            original_score (float): Original score for comparison.
            score_name (str): Name of the score metric.
            data_name (str): Name of the dataset.
            objective_direction (str): Objective direction (e.g., maximize or minimize).
            results_dir (str): Directory to save the plot.
        """
        plt.figure(figsize=(12, 8))

        plt.plot(n_feat, scores, marker='o', label='OpenFE Scores', color='blue', linewidth=2)
        plt.axhline(y=original_score, color='red', linestyle='--', label='Original Score', linewidth=2)

        # Add labels and title with improved formatting
        plt.xlabel('Number of Selected Features', fontsize=14)
        plt.ylabel(f'Mean Score ({score_name}) ', fontsize=14)

        plt.title(f'Performance of OpenFE on `{data_name}` (score: {score_name}, obj_dir: {objective_direction})', fontsize=15)
        
        # Add legend and grid for better readability
        plt.legend(fontsize=12)
        plt.grid(True, linestyle='--', alpha=0.7)

        if experiment_label:
            plt.figtext(0.5, 0.02, f'Experiment: {experiment_label}', ha='center', fontsize=10, style='italic')

        # plot best point if available
        if best_n_selected_features is not None and not (best_n_selected_features == 0):
            best_score = scores[n_feat.index(best_n_selected_features)]
            plt.scatter(best_n_selected_features, best_score, color='gold', s=300, marker='*', 
                        label='Best Result', edgecolors='black', linewidths=1.5, zorder=10)
            
            # Add an annotation next to the star
            plt.annotate(f'Best: {best_score:.2f}', 
                xy=(best_n_selected_features, best_score), 
                xytext=(best_n_selected_features+2, best_score),
                fontsize=12,
                weight='bold',
                arrowprops=dict(arrowstyle='->')
            )

        if save_plot:
            # Save the improved plot
            plot_path = os.path.join(results_dir, SCORES_PLOT_FILE)
            plt.savefig(plot_path, dpi=300)
            print(f"OpenFE Plot saved to {plot_path}")
            plt.close()
        else:
            plt.show()
            

    @staticmethod
    def load_results(experiment_result_dir, data_name):
        scores_file_path = os.path.join(experiment_result_dir, data_name, SCORES_FILE)
        experiment_metadata_file = os.path.join(experiment_result_dir, data_name, EXPE_META_DATA_FILE)
        results_df = FileUtils.load_csv(scores_file_path)
        experiment_metadata = FileUtils.load_json(experiment_metadata_file)

        return results_df, experiment_metadata 
    
    @staticmethod	
    def plot_comparison_scores(
        self,
        n_feat_lst, 
        scores_list, 
        score_labels_list, 
        original_score, 
        score_name, 
        objective_direction
    ):
        """
        Plot comparison of different score configurations.
        
        Parameters:
            n_feat_lst (list): Lists of feature counts for each configuration
            scores_list (list): Lists of scores for each configuration
            score_labels_list (list): Labels for each configuration
            original_score (float): Original score for comparison
            score_name (str): Name of the score metric
            objective_direction (str): "maximize" or "minimize"
        """
        if self.best_n_selected_features is None or self.best_score is None:
            print("Warning: best_n_selected_features or best_score not set. Call get_best_n_selected_features() first.")
            
        plt.figure(figsize=(12, 6))
        for scores, label, n_feat in zip(scores_list, score_labels_list, n_feat_lst):
            plt.plot(n_feat, scores, marker='o', label=label, linewidth=2)
        plt.axhline(y=original_score, color='red', linestyle='--', label='Original Score', linewidth=2)
        
        if self.best_n_selected_features is not None and self.best_score is not None:
            plt.scatter(self.best_n_selected_features, self.best_score, color='gold', s=300, marker='*', 
                        label='Best Result', edgecolors='black', linewidths=1.5, zorder=10)
            
            # Add an annotation next to the star
            plt.annotate(f'Best: {self.best_score:.2f}', 
                xy=(self.best_n_selected_features, self.best_score), 
                xytext=(self.best_n_selected_features+2, self.best_score),
                fontsize=12,
                weight='bold',
                arrowprops=dict(arrowstyle='->')
            )
        
        plt.xlabel('Number of Selected Features', fontsize=12)
        plt.ylabel(f'Mean Score ({score_name}) ', fontsize=12)
        plt.title(f'Performance of OpenFE on `{self.data_name}` Challenge (Score: {score_name}, Objective: {objective_direction})', fontsize=14)
        plt.legend(fontsize=12)
        plt.grid(True, linestyle='--', alpha=0.7)
        plt.show()

    @staticmethod
    def get_best_n_selected_features(results_df, objective_direction, original_score, n_digits_round=5):
        """
        Get the best number of selected features based on the mean score.
        """
        # TODO: should fix these hardcoded names and put them in constants and in a shared file
        if n_digits_round is None:
            results_df['rounded_mean_score'] = results_df['mean_score']
        else:
            results_df['rounded_mean_score'] = results_df['mean_score'].round(n_digits_round)
        
        if objective_direction == "maximize":
            best_row = results_df[results_df['rounded_mean_score'] == results_df['rounded_mean_score'].max()].nsmallest(1, 'n_selected_features')
        else:
            best_row = results_df[results_df['rounded_mean_score'] == results_df['rounded_mean_score'].min()].nsmallest(1, 'n_selected_features')
        
        best_score = best_row['mean_score'].iloc[0]
        best_score_rounded = best_row['rounded_mean_score'].iloc[0]

        improvement = score_is_better(best_score, original_score, objective_direction)

        if improvement:
            best_n_selected_features = best_row['n_selected_features'].iloc[0]
        else:
            best_n_selected_features = 0

        print(f"\nImprovement over original score: {improvement}")
        print(f"Best Score: {best_score}")
        print(f"Best Score Rounded: {best_score_rounded}")
        print(f"Best n_selected_features: {best_n_selected_features}")

        return best_n_selected_features, best_score
    
    @staticmethod
    def parse_OpenFE_feature_name(name: str) -> str:
        """
        Parses and modifies an OpenFE feature name string into a standardized format.

        Examples:
            - "Func(var1, var2)" -> "func__var1__var2"
            - "(var1*var2)" -> "var1__mul__var2"
            - "GroupByThenMean(var1, var2)" -> "gp_mean__var1__var2"
            - "CombineThenSum(var1, var2)" -> "cmb_sum__var1__var2"
            - "Func(var1)" -> "func__var1"
        """
        name = name.strip()
        
        # Operator mappings
        op_symbol_map = {'*': 'mul', '/': 'div', '+': 'add', '-': 'sub'}
        
        # Case 1: Infix operation like (var1*var2)
        # Matches content inside parentheses with a numerical operator
        infix_match = re.match(r'\(([^,()]+?)\s*([+\-*/])\s*([^,()]+?)\)', name)
        if infix_match:
            var1, op, var2 = infix_match.groups()
            op_name = op_symbol_map.get(op, op)
            return f"{var1.strip()}__{op_name}__{var2.strip()}"

        # Case 2: Function call like Func(var1, var2) or Func(var1)
        # Matches a function name and content within parentheses
        func_match = re.match(r'([A-Za-z_][A-Za-z0-9_]*)\((.*)\)', name)
        if func_match:
            func_name, content = func_match.groups()
            
            # Simplify GroupByThen... names
            if 'GroupByThen' in func_name:
                func_name = func_name.replace('GroupByThen', 'gp_').lower()
            if 'CombineThen' in func_name:
                func_name = func_name.replace('CombineThen', 'cmb_').lower()
            
            # Split variables by comma
            variables = [v.strip() for v in content.split(',')]
            
            return f"{func_name}__{'__'.join(variables)}"
            
        # Fallback for any other pattern
        return re.sub(r'[^a-zA-Z0-9_]+', '_', name).strip('_')

    @staticmethod
    def rename_OpenFE_columns(columns: list[str]) -> list[str]:
        """
        Applies the simplified parsing to a list of column names.
        """
        return [OpenFEUtils.parse_OpenFE_feature_name(c) for c in columns]

# %%
# versions = ["v2", "v3", "v4_5_folds", "v4_15_folds", "blend_4_models_v4_5_folds", "blend_4_models_v4_15_folds", "blend_4_models_v2", "blend_2_models_v2"]
versions = ["blend_2_models_v2", "blend_3_models_v2"]

for data_name in datasets:
    base_paths = get_base_paths(data_name, versions)
    
    for results_path in base_paths:
        try:
            print(f"\nProcessing {data_name} in {results_path}'")
            # make a copy of the original plot
            results_df, experiment_metadata = OpenFEUtils.load_results(results_path, "")
            orig_plot_path = os.path.join(results_path, SCORES_PLOT_FILE)
            if os.path.exists(orig_plot_path):
                dest_plot_path = os.path.join(results_path, f"original_{SCORES_PLOT_FILE}")
                print(dest_plot_path)
                shutil.copy(orig_plot_path, dest_plot_path)
                print(f"Copied original plot to {dest_plot_path}")

                # plot new openfe plot w best n selected features
                best_n_selected_feature = experiment_metadata['best_n_selected_features']
                OpenFEUtils.plot_and_save_scores(
                    n_feat=results_df['n_selected_features'].tolist(),
                    scores=results_df['mean_score'].tolist(),
                    results_dir=results_path,
                    original_score=experiment_metadata['original_score'],
                    score_name=experiment_metadata['score_name'],
                    data_name=data_name,
                    best_n_selected_features=best_n_selected_feature,
                    save_plot=True,
                    objective_direction=experiment_metadata['objective_direction']
                )

        except Exception as e:
            print(f"Error processing {data_name} in {results_path}: {e}")
            continue
# Out:
# Processing concrete_strength in ../openfe_experiments/openfe_kaggle_concrete_strength_10k_mcf_2_db_fb_False_grid_search_blend_2_models_v2/kaggle_concrete_strength'
# ../openfe_experiments/openfe_kaggle_concrete_strength_10k_mcf_2_db_fb_False_grid_search_blend_2_models_v2/kaggle_concrete_strength/original_openfe_scores_plot.png
# Copied original plot to ../openfe_experiments/openfe_kaggle_concrete_strength_10k_mcf_2_db_fb_False_grid_search_blend_2_models_v2/kaggle_concrete_strength/original_openfe_scores_plot.png
# OpenFE Plot saved to ../openfe_experiments/openfe_kaggle_concrete_strength_10k_mcf_2_db_fb_False_grid_search_blend_2_models_v2/kaggle_concrete_strength/openfe_scores_plot.png
#
# Processing concrete_strength in ../openfe_experiments/openfe_kaggle_concrete_strength_10k_mcf_2_db_fb_False_grid_search_blend_3_models_v2/kaggle_concrete_strength'
# ../openfe_experiments/openfe_kaggle_concrete_strength_10k_mcf_2_db_fb_False_grid_search_blend_3_models_v2/kaggle_concrete_strength/original_openfe_scores_plot.png
# Copied original plot to ../openfe_experiments/openfe_kaggle_concrete_strength_10k_mcf_2_db_fb_False_grid_search_blend_3_models_v2/kaggle_concrete_strength/original_openfe_scores_plot.png
# OpenFE Plot saved to ../openfe_experiments/openfe_kaggle_concrete_strength_10k_mcf_2_db_fb_False_grid_search_blend_3_models_v2/kaggle_concrete_strength/openfe_scores_plot.png
#
# Processing rainfall in ../openfe_experiments/openfe_kaggle_rainfall_10k_mcf_2_db_fb_False_grid_search_blend_2_models_v2/kaggle_rainfall'
# ../openfe_experiments/openfe_kaggle_rainfall_10k_mcf_2_db_fb_False_grid_search_blend_2_models_v2/kaggle_rainfall/original_openfe_scores_plot.png
# Copied original plot to ../openfe_experiments/openfe_kaggle_rainfall_10k_mcf_2_db_fb_False_grid_search_blend_2_models_v2/kaggle_rainfall/original_openfe_scores_plot.png
# OpenFE Plot saved to ../openfe_experiments/openfe_kaggle_rainfall_10k_mcf_2_db_fb_False_grid_search_blend_2_models_v2/kaggle_rainfall/openfe_scores_plot.png
#
# Processing rainfall in ../openfe_experiments/openfe_kaggle_rainfall_10k_mcf_2_db_fb_False_grid_search_blend_3_models_v2/kaggle_rainfall'
# ../openfe_experiments/openfe_kaggle_rainfall_10k_mcf_2_db_fb_False_grid_search_blend_3_models_v2/kaggle_rainfall/original_openfe_scores_plot.png
# Copied original plot to ../openfe_experiments/openfe_kaggle_rainfall_10k_mcf_2_db_fb_False_grid_search_blend_3_models_v2/kaggle_rainfall/original_openfe_scores_plot.png
# OpenFE Plot saved to ../openfe_experiments/openfe_kaggle_rainfall_10k_mcf_2_db_fb_False_grid_search_blend_3_models_v2/kaggle_rainfall/openfe_scores_plot.png
#
# Processing wine_quality in ../openfe_experiments/openfe_kaggle_wine_quality_10k_mcf_2_db_fb_False_grid_search_blend_2_models_v2/kaggle_wine_quality'
# ../openfe_experiments/openfe_kaggle_wine_quality_10k_mcf_2_db_fb_False_grid_search_blend_2_models_v2/kaggle_wine_quality/original_openfe_scores_plot.png
# Copied original plot to ../openfe_experiments/openfe_kaggle_wine_quality_10k_mcf_2_db_fb_False_grid_search_blend_2_models_v2/kaggle_wine_quality/original_openfe_scores_plot.png
# OpenFE Plot saved to ../openfe_experiments/openfe_kaggle_wine_quality_10k_mcf_2_db_fb_False_grid_search_blend_2_models_v2/kaggle_wine_quality/openfe_scores_plot.png
#
# Processing wine_quality in ../openfe_experiments/openfe_kaggle_wine_quality_10k_mcf_2_db_fb_False_grid_search_blend_3_models_v2/kaggle_wine_quality'
# ../openfe_experiments/openfe_kaggle_wine_quality_10k_mcf_2_db_fb_False_grid_search_blend_3_models_v2/kaggle_wine_quality/original_openfe_scores_plot.png
# Copied original plot to ../openfe_experiments/openfe_kaggle_wine_quality_10k_mcf_2_db_fb_False_grid_search_blend_3_models_v2/kaggle_wine_quality/original_openfe_scores_plot.png
# OpenFE Plot saved to ../openfe_experiments/openfe_kaggle_wine_quality_10k_mcf_2_db_fb_False_grid_search_blend_3_models_v2/kaggle_wine_quality/openfe_scores_plot.png
#
# Processing employee_attrition in ../openfe_experiments/openfe_kaggle_employee_attrition_10k_mcf_2_db_fb_False_grid_search_blend_2_models_v2/kaggle_employee_attrition'
# ../openfe_experiments/openfe_kaggle_employee_attrition_10k_mcf_2_db_fb_False_grid_search_blend_2_models_v2/kaggle_employee_attrition/original_openfe_scores_plot.png
# Copied original plot to ../openfe_experiments/openfe_kaggle_employee_attrition_10k_mcf_2_db_fb_False_grid_search_blend_2_models_v2/kaggle_employee_attrition/original_openfe_scores_plot.png
# OpenFE Plot saved to ../openfe_experiments/openfe_kaggle_employee_attrition_10k_mcf_2_db_fb_False_grid_search_blend_2_models_v2/kaggle_employee_attrition/openfe_scores_plot.png
#
# Processing employee_attrition in ../openfe_experiments/openfe_kaggle_employee_attrition_10k_mcf_2_db_fb_False_grid_search_blend_3_models_v2/kaggle_employee_attrition'
# ../openfe_experiments/openfe_kaggle_employee_attrition_10k_mcf_2_db_fb_False_grid_search_blend_3_models_v2/kaggle_employee_attrition/original_openfe_scores_plot.png
# Copied original plot to ../openfe_experiments/openfe_kaggle_employee_attrition_10k_mcf_2_db_fb_False_grid_search_blend_3_models_v2/kaggle_employee_attrition/original_openfe_scores_plot.png
# OpenFE Plot saved to ../openfe_experiments/openfe_kaggle_employee_attrition_10k_mcf_2_db_fb_False_grid_search_blend_3_models_v2/kaggle_employee_attrition/openfe_scores_plot.png
#
# Processing blueberry_yield in ../openfe_experiments/openfe_kaggle_blueberry_yield_10k_mcf_2_db_fb_False_grid_search_blend_2_models_v2/kaggle_blueberry_yield'
# ../openfe_experiments/openfe_kaggle_blueberry_yield_10k_mcf_2_db_fb_False_grid_search_blend_2_models_v2/kaggle_blueberry_yield/original_openfe_scores_plot.png
# Copied original plot to ../openfe_experiments/openfe_kaggle_blueberry_yield_10k_mcf_2_db_fb_False_grid_search_blend_2_models_v2/kaggle_blueberry_yield/original_openfe_scores_plot.png
# OpenFE Plot saved to ../openfe_experiments/openfe_kaggle_blueberry_yield_10k_mcf_2_db_fb_False_grid_search_blend_2_models_v2/kaggle_blueberry_yield/openfe_scores_plot.png
#
# Processing blueberry_yield in ../openfe_experiments/openfe_kaggle_blueberry_yield_10k_mcf_2_db_fb_False_grid_search_blend_3_models_v2/kaggle_blueberry_yield'
# ../openfe_experiments/openfe_kaggle_blueberry_yield_10k_mcf_2_db_fb_False_grid_search_blend_3_models_v2/kaggle_blueberry_yield/original_openfe_scores_plot.png
# Copied original plot to ../openfe_experiments/openfe_kaggle_blueberry_yield_10k_mcf_2_db_fb_False_grid_search_blend_3_models_v2/kaggle_blueberry_yield/original_openfe_scores_plot.png
# OpenFE Plot saved to ../openfe_experiments/openfe_kaggle_blueberry_yield_10k_mcf_2_db_fb_False_grid_search_blend_3_models_v2/kaggle_blueberry_yield/openfe_scores_plot.png
#
# Processing heat_flux in ../openfe_experiments/openfe_kaggle_heat_flux_10k_mcf_2_db_fb_False_grid_search_blend_2_models_v2/kaggle_heat_flux'
# ../openfe_experiments/openfe_kaggle_heat_flux_10k_mcf_2_db_fb_False_grid_search_blend_2_models_v2/kaggle_heat_flux/original_openfe_scores_plot.png
# Copied original plot to ../openfe_experiments/openfe_kaggle_heat_flux_10k_mcf_2_db_fb_False_grid_search_blend_2_models_v2/kaggle_heat_flux/original_openfe_scores_plot.png
# OpenFE Plot saved to ../openfe_experiments/openfe_kaggle_heat_flux_10k_mcf_2_db_fb_False_grid_search_blend_2_models_v2/kaggle_heat_flux/openfe_scores_plot.png
#
# Processing heat_flux in ../openfe_experiments/openfe_kaggle_heat_flux_10k_mcf_2_db_fb_False_grid_search_blend_3_models_v2/kaggle_heat_flux'
# ../openfe_experiments/openfe_kaggle_heat_flux_10k_mcf_2_db_fb_False_grid_search_blend_3_models_v2/kaggle_heat_flux/original_openfe_scores_plot.png
# Copied original plot to ../openfe_experiments/openfe_kaggle_heat_flux_10k_mcf_2_db_fb_False_grid_search_blend_3_models_v2/kaggle_heat_flux/original_openfe_scores_plot.png
# OpenFE Plot saved to ../openfe_experiments/openfe_kaggle_heat_flux_10k_mcf_2_db_fb_False_grid_search_blend_3_models_v2/kaggle_heat_flux/openfe_scores_plot.png
#
# Processing abalone in ../openfe_experiments/openfe_kaggle_abalone_10k_mcf_2_db_fb_False_grid_search_blend_2_models_v2/kaggle_abalone'
# ../openfe_experiments/openfe_kaggle_abalone_10k_mcf_2_db_fb_False_grid_search_blend_2_models_v2/kaggle_abalone/original_openfe_scores_plot.png
# Copied original plot to ../openfe_experiments/openfe_kaggle_abalone_10k_mcf_2_db_fb_False_grid_search_blend_2_models_v2/kaggle_abalone/original_openfe_scores_plot.png
# OpenFE Plot saved to ../openfe_experiments/openfe_kaggle_abalone_10k_mcf_2_db_fb_False_grid_search_blend_2_models_v2/kaggle_abalone/openfe_scores_plot.png
#
# Processing abalone in ../openfe_experiments/openfe_kaggle_abalone_10k_mcf_2_db_fb_False_grid_search_blend_3_models_v2/kaggle_abalone'
# ../openfe_experiments/openfe_kaggle_abalone_10k_mcf_2_db_fb_False_grid_search_blend_3_models_v2/kaggle_abalone/original_openfe_scores_plot.png
# Copied original plot to ../openfe_experiments/openfe_kaggle_abalone_10k_mcf_2_db_fb_False_grid_search_blend_3_models_v2/kaggle_abalone/original_openfe_scores_plot.png
# OpenFE Plot saved to ../openfe_experiments/openfe_kaggle_abalone_10k_mcf_2_db_fb_False_grid_search_blend_3_models_v2/kaggle_abalone/openfe_scores_plot.png
#
# Processing mohs_hardness in ../openfe_experiments/openfe_kaggle_mohs_hardness_10k_mcf_2_db_fb_False_grid_search_blend_2_models_v2/kaggle_mohs_hardness'
# ../openfe_experiments/openfe_kaggle_mohs_hardness_10k_mcf_2_db_fb_False_grid_search_blend_2_models_v2/kaggle_mohs_hardness/original_openfe_scores_plot.png
# Copied original plot to ../openfe_experiments/openfe_kaggle_mohs_hardness_10k_mcf_2_db_fb_False_grid_search_blend_2_models_v2/kaggle_mohs_hardness/original_openfe_scores_plot.png
# OpenFE Plot saved to ../openfe_experiments/openfe_kaggle_mohs_hardness_10k_mcf_2_db_fb_False_grid_search_blend_2_models_v2/kaggle_mohs_hardness/openfe_scores_plot.png
#
# Processing mohs_hardness in ../openfe_experiments/openfe_kaggle_mohs_hardness_10k_mcf_2_db_fb_False_grid_search_blend_3_models_v2/kaggle_mohs_hardness'
# ../openfe_experiments/openfe_kaggle_mohs_hardness_10k_mcf_2_db_fb_False_grid_search_blend_3_models_v2/kaggle_mohs_hardness/original_openfe_scores_plot.png
# Copied original plot to ../openfe_experiments/openfe_kaggle_mohs_hardness_10k_mcf_2_db_fb_False_grid_search_blend_3_models_v2/kaggle_mohs_hardness/original_openfe_scores_plot.png
# OpenFE Plot saved to ../openfe_experiments/openfe_kaggle_mohs_hardness_10k_mcf_2_db_fb_False_grid_search_blend_3_models_v2/kaggle_mohs_hardness/openfe_scores_plot.png
#
# Processing crab_age in ../openfe_experiments/openfe_kaggle_crab_age_10k_mcf_2_db_fb_False_grid_search_blend_2_models_v2/kaggle_crab_age'
# ../openfe_experiments/openfe_kaggle_crab_age_10k_mcf_2_db_fb_False_grid_search_blend_2_models_v2/kaggle_crab_age/original_openfe_scores_plot.png
# Copied original plot to ../openfe_experiments/openfe_kaggle_crab_age_10k_mcf_2_db_fb_False_grid_search_blend_2_models_v2/kaggle_crab_age/original_openfe_scores_plot.png
# OpenFE Plot saved to ../openfe_experiments/openfe_kaggle_crab_age_10k_mcf_2_db_fb_False_grid_search_blend_2_models_v2/kaggle_crab_age/openfe_scores_plot.png
#
# Processing crab_age in ../openfe_experiments/openfe_kaggle_crab_age_10k_mcf_2_db_fb_False_grid_search_blend_3_models_v2/kaggle_crab_age'
# ../openfe_experiments/openfe_kaggle_crab_age_10k_mcf_2_db_fb_False_grid_search_blend_3_models_v2/kaggle_crab_age/original_openfe_scores_plot.png
# Copied original plot to ../openfe_experiments/openfe_kaggle_crab_age_10k_mcf_2_db_fb_False_grid_search_blend_3_models_v2/kaggle_crab_age/original_openfe_scores_plot.png
# OpenFE Plot saved to ../openfe_experiments/openfe_kaggle_crab_age_10k_mcf_2_db_fb_False_grid_search_blend_3_models_v2/kaggle_crab_age/openfe_scores_plot.png
#
# Processing housing_price_california in ../openfe_experiments/openfe_kaggle_housing_price_california_10k_mcf_2_db_fb_False_grid_search_blend_2_models_v2/kaggle_housing_price_california'
# ../openfe_experiments/openfe_kaggle_housing_price_california_10k_mcf_2_db_fb_False_grid_search_blend_2_models_v2/kaggle_housing_price_california/original_openfe_scores_plot.png
# Copied original plot to ../openfe_experiments/openfe_kaggle_housing_price_california_10k_mcf_2_db_fb_False_grid_search_blend_2_models_v2/kaggle_housing_price_california/original_openfe_scores_plot.png
# OpenFE Plot saved to ../openfe_experiments/openfe_kaggle_housing_price_california_10k_mcf_2_db_fb_False_grid_search_blend_2_models_v2/kaggle_housing_price_california/openfe_scores_plot.png
#
# Processing housing_price_california in ../openfe_experiments/openfe_kaggle_housing_price_california_10k_mcf_2_db_fb_False_grid_search_blend_3_models_v2/kaggle_housing_price_california'
# ../openfe_experiments/openfe_kaggle_housing_price_california_10k_mcf_2_db_fb_False_grid_search_blend_3_models_v2/kaggle_housing_price_california/original_openfe_scores_plot.png
# Copied original plot to ../openfe_experiments/openfe_kaggle_housing_price_california_10k_mcf_2_db_fb_False_grid_search_blend_3_models_v2/kaggle_housing_price_california/original_openfe_scores_plot.png
# OpenFE Plot saved to ../openfe_experiments/openfe_kaggle_housing_price_california_10k_mcf_2_db_fb_False_grid_search_blend_3_models_v2/kaggle_housing_price_california/openfe_scores_plot.png
#
# Processing influencer in ../openfe_experiments/openfe_kaggle_influencer_10k_mcf_2_db_fb_False_grid_search_blend_2_models_v2/kaggle_influencer'
# ../openfe_experiments/openfe_kaggle_influencer_10k_mcf_2_db_fb_False_grid_search_blend_2_models_v2/kaggle_influencer/original_openfe_scores_plot.png
# Copied original plot to ../openfe_experiments/openfe_kaggle_influencer_10k_mcf_2_db_fb_False_grid_search_blend_2_models_v2/kaggle_influencer/original_openfe_scores_plot.png
# OpenFE Plot saved to ../openfe_experiments/openfe_kaggle_influencer_10k_mcf_2_db_fb_False_grid_search_blend_2_models_v2/kaggle_influencer/openfe_scores_plot.png
#
# Processing influencer in ../openfe_experiments/openfe_kaggle_influencer_10k_mcf_2_db_fb_False_grid_search_blend_3_models_v2/kaggle_influencer'
# ../openfe_experiments/openfe_kaggle_influencer_10k_mcf_2_db_fb_False_grid_search_blend_3_models_v2/kaggle_influencer/original_openfe_scores_plot.png
# Copied original plot to ../openfe_experiments/openfe_kaggle_influencer_10k_mcf_2_db_fb_False_grid_search_blend_3_models_v2/kaggle_influencer/original_openfe_scores_plot.png
# OpenFE Plot saved to ../openfe_experiments/openfe_kaggle_influencer_10k_mcf_2_db_fb_False_grid_search_blend_3_models_v2/kaggle_influencer/openfe_scores_plot.png
#
# Processing cirrhosis_outcomes in ../openfe_experiments/openfe_kaggle_cirrhosis_outcomes_10k_mcf_2_db_fb_False_grid_search_blend_2_models_v2/kaggle_cirrhosis_outcomes'
# ../openfe_experiments/openfe_kaggle_cirrhosis_outcomes_10k_mcf_2_db_fb_False_grid_search_blend_2_models_v2/kaggle_cirrhosis_outcomes/original_openfe_scores_plot.png
# Copied original plot to ../openfe_experiments/openfe_kaggle_cirrhosis_outcomes_10k_mcf_2_db_fb_False_grid_search_blend_2_models_v2/kaggle_cirrhosis_outcomes/original_openfe_scores_plot.png
# OpenFE Plot saved to ../openfe_experiments/openfe_kaggle_cirrhosis_outcomes_10k_mcf_2_db_fb_False_grid_search_blend_2_models_v2/kaggle_cirrhosis_outcomes/openfe_scores_plot.png
#
# Processing cirrhosis_outcomes in ../openfe_experiments/openfe_kaggle_cirrhosis_outcomes_10k_mcf_2_db_fb_False_grid_search_blend_3_models_v2/kaggle_cirrhosis_outcomes'
# ../openfe_experiments/openfe_kaggle_cirrhosis_outcomes_10k_mcf_2_db_fb_False_grid_search_blend_3_models_v2/kaggle_cirrhosis_outcomes/original_openfe_scores_plot.png
# Copied original plot to ../openfe_experiments/openfe_kaggle_cirrhosis_outcomes_10k_mcf_2_db_fb_False_grid_search_blend_3_models_v2/kaggle_cirrhosis_outcomes/original_openfe_scores_plot.png
# OpenFE Plot saved to ../openfe_experiments/openfe_kaggle_cirrhosis_outcomes_10k_mcf_2_db_fb_False_grid_search_blend_3_models_v2/kaggle_cirrhosis_outcomes/openfe_scores_plot.png
#
# Processing sticker_sales in ../openfe_experiments/openfe_kaggle_sticker_sales_10k_mcf_2_db_fb_False_grid_search_blend_2_models_v2/kaggle_sticker_sales'
# Error processing sticker_sales in ../openfe_experiments/openfe_kaggle_sticker_sales_10k_mcf_2_db_fb_False_grid_search_blend_2_models_v2/kaggle_sticker_sales: [Errno 2] No such file or directory: '../openfe_experiments/openfe_kaggle_sticker_sales_10k_mcf_2_db_fb_False_grid_search_blend_2_models_v2/kaggle_sticker_sales/scores.csv'
#
# Processing sticker_sales in ../openfe_experiments/openfe_kaggle_sticker_sales_10k_mcf_2_db_fb_False_grid_search_blend_3_models_v2/kaggle_sticker_sales'
# Error processing sticker_sales in ../openfe_experiments/openfe_kaggle_sticker_sales_10k_mcf_2_db_fb_False_grid_search_blend_3_models_v2/kaggle_sticker_sales: [Errno 2] No such file or directory: '../openfe_experiments/openfe_kaggle_sticker_sales_10k_mcf_2_db_fb_False_grid_search_blend_3_models_v2/kaggle_sticker_sales/scores.csv'
#
# Processing reservation_cancellation in ../openfe_experiments/openfe_kaggle_reservation_cancellation_10k_mcf_2_db_fb_False_grid_search_blend_2_models_v2/kaggle_reservation_cancellation'
# ../openfe_experiments/openfe_kaggle_reservation_cancellation_10k_mcf_2_db_fb_False_grid_search_blend_2_models_v2/kaggle_reservation_cancellation/original_openfe_scores_plot.png
# Copied original plot to ../openfe_experiments/openfe_kaggle_reservation_cancellation_10k_mcf_2_db_fb_False_grid_search_blend_2_models_v2/kaggle_reservation_cancellation/original_openfe_scores_plot.png
# OpenFE Plot saved to ../openfe_experiments/openfe_kaggle_reservation_cancellation_10k_mcf_2_db_fb_False_grid_search_blend_2_models_v2/kaggle_reservation_cancellation/openfe_scores_plot.png
#
# Processing reservation_cancellation in ../openfe_experiments/openfe_kaggle_reservation_cancellation_10k_mcf_2_db_fb_False_grid_search_blend_3_models_v2/kaggle_reservation_cancellation'
# ../openfe_experiments/openfe_kaggle_reservation_cancellation_10k_mcf_2_db_fb_False_grid_search_blend_3_models_v2/kaggle_reservation_cancellation/original_openfe_scores_plot.png
# Copied original plot to ../openfe_experiments/openfe_kaggle_reservation_cancellation_10k_mcf_2_db_fb_False_grid_search_blend_3_models_v2/kaggle_reservation_cancellation/original_openfe_scores_plot.png
# OpenFE Plot saved to ../openfe_experiments/openfe_kaggle_reservation_cancellation_10k_mcf_2_db_fb_False_grid_search_blend_3_models_v2/kaggle_reservation_cancellation/openfe_scores_plot.png
#
# Processing obesity_risk in ../openfe_experiments/openfe_kaggle_obesity_risk_10k_mcf_2_db_fb_False_grid_search_blend_2_models_v2/kaggle_obesity_risk'
# ../openfe_experiments/openfe_kaggle_obesity_risk_10k_mcf_2_db_fb_False_grid_search_blend_2_models_v2/kaggle_obesity_risk/original_openfe_scores_plot.png
# Copied original plot to ../openfe_experiments/openfe_kaggle_obesity_risk_10k_mcf_2_db_fb_False_grid_search_blend_2_models_v2/kaggle_obesity_risk/original_openfe_scores_plot.png
# OpenFE Plot saved to ../openfe_experiments/openfe_kaggle_obesity_risk_10k_mcf_2_db_fb_False_grid_search_blend_2_models_v2/kaggle_obesity_risk/openfe_scores_plot.png
#
# Processing obesity_risk in ../openfe_experiments/openfe_kaggle_obesity_risk_10k_mcf_2_db_fb_False_grid_search_blend_3_models_v2/kaggle_obesity_risk'
# ../openfe_experiments/openfe_kaggle_obesity_risk_10k_mcf_2_db_fb_False_grid_search_blend_3_models_v2/kaggle_obesity_risk/original_openfe_scores_plot.png
# Copied original plot to ../openfe_experiments/openfe_kaggle_obesity_risk_10k_mcf_2_db_fb_False_grid_search_blend_3_models_v2/kaggle_obesity_risk/original_openfe_scores_plot.png
# OpenFE Plot saved to ../openfe_experiments/openfe_kaggle_obesity_risk_10k_mcf_2_db_fb_False_grid_search_blend_3_models_v2/kaggle_obesity_risk/openfe_scores_plot.png
#
# Processing loan_approval in ../openfe_experiments/openfe_kaggle_loan_approval_10k_mcf_2_db_fb_False_grid_search_blend_2_models_v2/kaggle_loan_approval'
# ../openfe_experiments/openfe_kaggle_loan_approval_10k_mcf_2_db_fb_False_grid_search_blend_2_models_v2/kaggle_loan_approval/original_openfe_scores_plot.png
# Copied original plot to ../openfe_experiments/openfe_kaggle_loan_approval_10k_mcf_2_db_fb_False_grid_search_blend_2_models_v2/kaggle_loan_approval/original_openfe_scores_plot.png
# OpenFE Plot saved to ../openfe_experiments/openfe_kaggle_loan_approval_10k_mcf_2_db_fb_False_grid_search_blend_2_models_v2/kaggle_loan_approval/openfe_scores_plot.png
#
# Processing loan_approval in ../openfe_experiments/openfe_kaggle_loan_approval_10k_mcf_2_db_fb_False_grid_search_blend_3_models_v2/kaggle_loan_approval'
# ../openfe_experiments/openfe_kaggle_loan_approval_10k_mcf_2_db_fb_False_grid_search_blend_3_models_v2/kaggle_loan_approval/original_openfe_scores_plot.png
# Copied original plot to ../openfe_experiments/openfe_kaggle_loan_approval_10k_mcf_2_db_fb_False_grid_search_blend_3_models_v2/kaggle_loan_approval/original_openfe_scores_plot.png
# OpenFE Plot saved to ../openfe_experiments/openfe_kaggle_loan_approval_10k_mcf_2_db_fb_False_grid_search_blend_3_models_v2/kaggle_loan_approval/openfe_scores_plot.png
#
# Processing calorie_expenditure in ../openfe_experiments/openfe_kaggle_calorie_expenditure_10k_mcf_2_db_fb_False_grid_search_blend_2_models_v2/kaggle_calorie_expenditure'
# ../openfe_experiments/openfe_kaggle_calorie_expenditure_10k_mcf_2_db_fb_False_grid_search_blend_2_models_v2/kaggle_calorie_expenditure/original_openfe_scores_plot.png
# Copied original plot to ../openfe_experiments/openfe_kaggle_calorie_expenditure_10k_mcf_2_db_fb_False_grid_search_blend_2_models_v2/kaggle_calorie_expenditure/original_openfe_scores_plot.png
# OpenFE Plot saved to ../openfe_experiments/openfe_kaggle_calorie_expenditure_10k_mcf_2_db_fb_False_grid_search_blend_2_models_v2/kaggle_calorie_expenditure/openfe_scores_plot.png
#
# Processing calorie_expenditure in ../openfe_experiments/openfe_kaggle_calorie_expenditure_10k_mcf_2_db_fb_False_grid_search_blend_3_models_v2/kaggle_calorie_expenditure'
# ../openfe_experiments/openfe_kaggle_calorie_expenditure_10k_mcf_2_db_fb_False_grid_search_blend_3_models_v2/kaggle_calorie_expenditure/original_openfe_scores_plot.png
# Copied original plot to ../openfe_experiments/openfe_kaggle_calorie_expenditure_10k_mcf_2_db_fb_False_grid_search_blend_3_models_v2/kaggle_calorie_expenditure/original_openfe_scores_plot.png
# OpenFE Plot saved to ../openfe_experiments/openfe_kaggle_calorie_expenditure_10k_mcf_2_db_fb_False_grid_search_blend_3_models_v2/kaggle_calorie_expenditure/openfe_scores_plot.png
#
# Processing credit_fusion in ../openfe_experiments/openfe_kaggle_credit_fusion_10k_mcf_2_db_fb_False_grid_search_blend_2_models_v2/kaggle_credit_fusion'
# ../openfe_experiments/openfe_kaggle_credit_fusion_10k_mcf_2_db_fb_False_grid_search_blend_2_models_v2/kaggle_credit_fusion/original_openfe_scores_plot.png
# Copied original plot to ../openfe_experiments/openfe_kaggle_credit_fusion_10k_mcf_2_db_fb_False_grid_search_blend_2_models_v2/kaggle_credit_fusion/original_openfe_scores_plot.png
# OpenFE Plot saved to ../openfe_experiments/openfe_kaggle_credit_fusion_10k_mcf_2_db_fb_False_grid_search_blend_2_models_v2/kaggle_credit_fusion/openfe_scores_plot.png
#
# Processing credit_fusion in ../openfe_experiments/openfe_kaggle_credit_fusion_10k_mcf_2_db_fb_False_grid_search_blend_3_models_v2/kaggle_credit_fusion'
# ../openfe_experiments/openfe_kaggle_credit_fusion_10k_mcf_2_db_fb_False_grid_search_blend_3_models_v2/kaggle_credit_fusion/original_openfe_scores_plot.png
# Copied original plot to ../openfe_experiments/openfe_kaggle_credit_fusion_10k_mcf_2_db_fb_False_grid_search_blend_3_models_v2/kaggle_credit_fusion/original_openfe_scores_plot.png
# OpenFE Plot saved to ../openfe_experiments/openfe_kaggle_credit_fusion_10k_mcf_2_db_fb_False_grid_search_blend_3_models_v2/kaggle_credit_fusion/openfe_scores_plot.png
#
# Processing bank_churn in ../openfe_experiments/openfe_kaggle_bank_churn_10k_mcf_2_db_fb_False_grid_search_blend_2_models_v2/kaggle_bank_churn'
# ../openfe_experiments/openfe_kaggle_bank_churn_10k_mcf_2_db_fb_False_grid_search_blend_2_models_v2/kaggle_bank_churn/original_openfe_scores_plot.png
# Copied original plot to ../openfe_experiments/openfe_kaggle_bank_churn_10k_mcf_2_db_fb_False_grid_search_blend_2_models_v2/kaggle_bank_churn/original_openfe_scores_plot.png
# OpenFE Plot saved to ../openfe_experiments/openfe_kaggle_bank_churn_10k_mcf_2_db_fb_False_grid_search_blend_2_models_v2/kaggle_bank_churn/openfe_scores_plot.png
#
# Processing bank_churn in ../openfe_experiments/openfe_kaggle_bank_churn_10k_mcf_2_db_fb_False_grid_search_blend_3_models_v2/kaggle_bank_churn'
# ../openfe_experiments/openfe_kaggle_bank_churn_10k_mcf_2_db_fb_False_grid_search_blend_3_models_v2/kaggle_bank_churn/original_openfe_scores_plot.png
# Copied original plot to ../openfe_experiments/openfe_kaggle_bank_churn_10k_mcf_2_db_fb_False_grid_search_blend_3_models_v2/kaggle_bank_churn/original_openfe_scores_plot.png
# OpenFE Plot saved to ../openfe_experiments/openfe_kaggle_bank_churn_10k_mcf_2_db_fb_False_grid_search_blend_3_models_v2/kaggle_bank_churn/openfe_scores_plot.png
#
# Processing failure in ../openfe_experiments/openfe_kaggle_failure_10k_mcf_2_db_fb_False_grid_search_blend_2_models_v2/kaggle_failure'
# ../openfe_experiments/openfe_kaggle_failure_10k_mcf_2_db_fb_False_grid_search_blend_2_models_v2/kaggle_failure/original_openfe_scores_plot.png
# Copied original plot to ../openfe_experiments/openfe_kaggle_failure_10k_mcf_2_db_fb_False_grid_search_blend_2_models_v2/kaggle_failure/original_openfe_scores_plot.png
# OpenFE Plot saved to ../openfe_experiments/openfe_kaggle_failure_10k_mcf_2_db_fb_False_grid_search_blend_2_models_v2/kaggle_failure/openfe_scores_plot.png
#
# Processing failure in ../openfe_experiments/openfe_kaggle_failure_10k_mcf_2_db_fb_False_grid_search_blend_3_models_v2/kaggle_failure'
# ../openfe_experiments/openfe_kaggle_failure_10k_mcf_2_db_fb_False_grid_search_blend_3_models_v2/kaggle_failure/original_openfe_scores_plot.png
# Copied original plot to ../openfe_experiments/openfe_kaggle_failure_10k_mcf_2_db_fb_False_grid_search_blend_3_models_v2/kaggle_failure/original_openfe_scores_plot.png
# OpenFE Plot saved to ../openfe_experiments/openfe_kaggle_failure_10k_mcf_2_db_fb_False_grid_search_blend_3_models_v2/kaggle_failure/openfe_scores_plot.png
#
# Processing unknown_a in ../openfe_experiments/openfe_kaggle_unknown_a_10k_mcf_2_db_fb_False_grid_search_blend_2_models_v2/kaggle_unknown_a'
# ../openfe_experiments/openfe_kaggle_unknown_a_10k_mcf_2_db_fb_False_grid_search_blend_2_models_v2/kaggle_unknown_a/original_openfe_scores_plot.png
# Copied original plot to ../openfe_experiments/openfe_kaggle_unknown_a_10k_mcf_2_db_fb_False_grid_search_blend_2_models_v2/kaggle_unknown_a/original_openfe_scores_plot.png
# OpenFE Plot saved to ../openfe_experiments/openfe_kaggle_unknown_a_10k_mcf_2_db_fb_False_grid_search_blend_2_models_v2/kaggle_unknown_a/openfe_scores_plot.png
#
# Processing unknown_a in ../openfe_experiments/openfe_kaggle_unknown_a_10k_mcf_2_db_fb_False_grid_search_blend_3_models_v2/kaggle_unknown_a'
# ../openfe_experiments/openfe_kaggle_unknown_a_10k_mcf_2_db_fb_False_grid_search_blend_3_models_v2/kaggle_unknown_a/original_openfe_scores_plot.png
# Copied original plot to ../openfe_experiments/openfe_kaggle_unknown_a_10k_mcf_2_db_fb_False_grid_search_blend_3_models_v2/kaggle_unknown_a/original_openfe_scores_plot.png
# OpenFE Plot saved to ../openfe_experiments/openfe_kaggle_unknown_a_10k_mcf_2_db_fb_False_grid_search_blend_3_models_v2/kaggle_unknown_a/openfe_scores_plot.png
#
# Processing horse_survival in ../openfe_experiments/openfe_kaggle_horse_survival_10k_mcf_2_db_fb_False_grid_search_blend_2_models_v2/kaggle_horse_survival'
# Error processing horse_survival in ../openfe_experiments/openfe_kaggle_horse_survival_10k_mcf_2_db_fb_False_grid_search_blend_2_models_v2/kaggle_horse_survival: [Errno 2] No such file or directory: '../openfe_experiments/openfe_kaggle_horse_survival_10k_mcf_2_db_fb_False_grid_search_blend_2_models_v2/kaggle_horse_survival/scores.csv'
#
# Processing horse_survival in ../openfe_experiments/openfe_kaggle_horse_survival_10k_mcf_2_db_fb_False_grid_search_blend_3_models_v2/kaggle_horse_survival'
# Error processing horse_survival in ../openfe_experiments/openfe_kaggle_horse_survival_10k_mcf_2_db_fb_False_grid_search_blend_3_models_v2/kaggle_horse_survival: [Errno 2] No such file or directory: '../openfe_experiments/openfe_kaggle_horse_survival_10k_mcf_2_db_fb_False_grid_search_blend_3_models_v2/kaggle_horse_survival/scores.csv'
#
# Processing media_cost in ../openfe_experiments/openfe_kaggle_media_cost_10k_mcf_2_db_fb_False_grid_search_blend_2_models_v2/kaggle_media_cost'
# Error processing media_cost in ../openfe_experiments/openfe_kaggle_media_cost_10k_mcf_2_db_fb_False_grid_search_blend_2_models_v2/kaggle_media_cost: [Errno 2] No such file or directory: '../openfe_experiments/openfe_kaggle_media_cost_10k_mcf_2_db_fb_False_grid_search_blend_2_models_v2/kaggle_media_cost/scores.csv'
#
# Processing media_cost in ../openfe_experiments/openfe_kaggle_media_cost_10k_mcf_2_db_fb_False_grid_search_blend_3_models_v2/kaggle_media_cost'
# ../openfe_experiments/openfe_kaggle_media_cost_10k_mcf_2_db_fb_False_grid_search_blend_3_models_v2/kaggle_media_cost/original_openfe_scores_plot.png
# Copied original plot to ../openfe_experiments/openfe_kaggle_media_cost_10k_mcf_2_db_fb_False_grid_search_blend_3_models_v2/kaggle_media_cost/original_openfe_scores_plot.png
# OpenFE Plot saved to ../openfe_experiments/openfe_kaggle_media_cost_10k_mcf_2_db_fb_False_grid_search_blend_3_models_v2/kaggle_media_cost/openfe_scores_plot.png
#
# Processing smoking in ../openfe_experiments/openfe_kaggle_smoking_10k_mcf_2_db_fb_False_grid_search_blend_2_models_v2/kaggle_smoking'
# Error processing smoking in ../openfe_experiments/openfe_kaggle_smoking_10k_mcf_2_db_fb_False_grid_search_blend_2_models_v2/kaggle_smoking: [Errno 2] No such file or directory: '../openfe_experiments/openfe_kaggle_smoking_10k_mcf_2_db_fb_False_grid_search_blend_2_models_v2/kaggle_smoking/scores.csv'
#
# Processing smoking in ../openfe_experiments/openfe_kaggle_smoking_10k_mcf_2_db_fb_False_grid_search_blend_3_models_v2/kaggle_smoking'
# ../openfe_experiments/openfe_kaggle_smoking_10k_mcf_2_db_fb_False_grid_search_blend_3_models_v2/kaggle_smoking/original_openfe_scores_plot.png
# Copied original plot to ../openfe_experiments/openfe_kaggle_smoking_10k_mcf_2_db_fb_False_grid_search_blend_3_models_v2/kaggle_smoking/original_openfe_scores_plot.png
# OpenFE Plot saved to ../openfe_experiments/openfe_kaggle_smoking_10k_mcf_2_db_fb_False_grid_search_blend_3_models_v2/kaggle_smoking/openfe_scores_plot.png
#
# Processing mercedes_testing_time in ../openfe_experiments/openfe_kaggle_mercedes_testing_time_10k_mcf_2_db_fb_False_grid_search_blend_2_models_v2/kaggle_mercedes_testing_time'
# Error processing mercedes_testing_time in ../openfe_experiments/openfe_kaggle_mercedes_testing_time_10k_mcf_2_db_fb_False_grid_search_blend_2_models_v2/kaggle_mercedes_testing_time: [Errno 2] No such file or directory: '../openfe_experiments/openfe_kaggle_mercedes_testing_time_10k_mcf_2_db_fb_False_grid_search_blend_2_models_v2/kaggle_mercedes_testing_time/scores.csv'
#
# Processing mercedes_testing_time in ../openfe_experiments/openfe_kaggle_mercedes_testing_time_10k_mcf_2_db_fb_False_grid_search_blend_3_models_v2/kaggle_mercedes_testing_time'
# ../openfe_experiments/openfe_kaggle_mercedes_testing_time_10k_mcf_2_db_fb_False_grid_search_blend_3_models_v2/kaggle_mercedes_testing_time/original_openfe_scores_plot.png
# Copied original plot to ../openfe_experiments/openfe_kaggle_mercedes_testing_time_10k_mcf_2_db_fb_False_grid_search_blend_3_models_v2/kaggle_mercedes_testing_time/original_openfe_scores_plot.png
# OpenFE Plot saved to ../openfe_experiments/openfe_kaggle_mercedes_testing_time_10k_mcf_2_db_fb_False_grid_search_blend_3_models_v2/kaggle_mercedes_testing_time/openfe_scores_plot.png
#
# Processing insurance_claim in ../openfe_experiments/openfe_kaggle_insurance_claim_10k_mcf_2_db_fb_False_grid_search_blend_2_models_v2/kaggle_insurance_claim'
# Error processing insurance_claim in ../openfe_experiments/openfe_kaggle_insurance_claim_10k_mcf_2_db_fb_False_grid_search_blend_2_models_v2/kaggle_insurance_claim: [Errno 2] No such file or directory: '../openfe_experiments/openfe_kaggle_insurance_claim_10k_mcf_2_db_fb_False_grid_search_blend_2_models_v2/kaggle_insurance_claim/scores.csv'
#
# Processing insurance_claim in ../openfe_experiments/openfe_kaggle_insurance_claim_10k_mcf_2_db_fb_False_grid_search_blend_3_models_v2/kaggle_insurance_claim'
# ../openfe_experiments/openfe_kaggle_insurance_claim_10k_mcf_2_db_fb_False_grid_search_blend_3_models_v2/kaggle_insurance_claim/original_openfe_scores_plot.png
# Copied original plot to ../openfe_experiments/openfe_kaggle_insurance_claim_10k_mcf_2_db_fb_False_grid_search_blend_3_models_v2/kaggle_insurance_claim/original_openfe_scores_plot.png
# OpenFE Plot saved to ../openfe_experiments/openfe_kaggle_insurance_claim_10k_mcf_2_db_fb_False_grid_search_blend_3_models_v2/kaggle_insurance_claim/openfe_scores_plot.png
#
# Processing synthanic in ../openfe_experiments/openfe_kaggle_synthanic_10k_mcf_2_db_fb_False_grid_search_blend_2_models_v2/kaggle_synthanic'
# Error processing synthanic in ../openfe_experiments/openfe_kaggle_synthanic_10k_mcf_2_db_fb_False_grid_search_blend_2_models_v2/kaggle_synthanic: [Errno 2] No such file or directory: '../openfe_experiments/openfe_kaggle_synthanic_10k_mcf_2_db_fb_False_grid_search_blend_2_models_v2/kaggle_synthanic/scores.csv'
#
# Processing synthanic in ../openfe_experiments/openfe_kaggle_synthanic_10k_mcf_2_db_fb_False_grid_search_blend_3_models_v2/kaggle_synthanic'
# Error processing synthanic in ../openfe_experiments/openfe_kaggle_synthanic_10k_mcf_2_db_fb_False_grid_search_blend_3_models_v2/kaggle_synthanic: [Errno 2] No such file or directory: '../openfe_experiments/openfe_kaggle_synthanic_10k_mcf_2_db_fb_False_grid_search_blend_3_models_v2/kaggle_synthanic/scores.csv'
#
# Processing mental_health in ../openfe_experiments/openfe_kaggle_mental_health_10k_mcf_2_db_fb_False_grid_search_blend_2_models_v2/kaggle_mental_health'
# Error processing mental_health in ../openfe_experiments/openfe_kaggle_mental_health_10k_mcf_2_db_fb_False_grid_search_blend_2_models_v2/kaggle_mental_health: [Errno 2] No such file or directory: '../openfe_experiments/openfe_kaggle_mental_health_10k_mcf_2_db_fb_False_grid_search_blend_2_models_v2/kaggle_mental_health/scores.csv'
#
# Processing mental_health in ../openfe_experiments/openfe_kaggle_mental_health_10k_mcf_2_db_fb_False_grid_search_blend_3_models_v2/kaggle_mental_health'
# Error processing mental_health in ../openfe_experiments/openfe_kaggle_mental_health_10k_mcf_2_db_fb_False_grid_search_blend_3_models_v2/kaggle_mental_health: [Errno 2] No such file or directory: '../openfe_experiments/openfe_kaggle_mental_health_10k_mcf_2_db_fb_False_grid_search_blend_3_models_v2/kaggle_mental_health/scores.csv'
#
# Processing flood_probability in ../openfe_experiments/openfe_kaggle_flood_probability_10k_mcf_2_db_fb_False_grid_search_blend_2_models_v2/kaggle_flood_probability'
# Error processing flood_probability in ../openfe_experiments/openfe_kaggle_flood_probability_10k_mcf_2_db_fb_False_grid_search_blend_2_models_v2/kaggle_flood_probability: [Errno 2] No such file or directory: '../openfe_experiments/openfe_kaggle_flood_probability_10k_mcf_2_db_fb_False_grid_search_blend_2_models_v2/kaggle_flood_probability/scores.csv'
#
# Processing flood_probability in ../openfe_experiments/openfe_kaggle_flood_probability_10k_mcf_2_db_fb_False_grid_search_blend_3_models_v2/kaggle_flood_probability'
# ../openfe_experiments/openfe_kaggle_flood_probability_10k_mcf_2_db_fb_False_grid_search_blend_3_models_v2/kaggle_flood_probability/original_openfe_scores_plot.png
# Copied original plot to ../openfe_experiments/openfe_kaggle_flood_probability_10k_mcf_2_db_fb_False_grid_search_blend_3_models_v2/kaggle_flood_probability/original_openfe_scores_plot.png
# OpenFE Plot saved to ../openfe_experiments/openfe_kaggle_flood_probability_10k_mcf_2_db_fb_False_grid_search_blend_3_models_v2/kaggle_flood_probability/openfe_scores_plot.png
#
# Processing insurance_premium in ../openfe_experiments/openfe_kaggle_insurance_premium_10k_mcf_2_db_fb_False_grid_search_blend_2_models_v2/kaggle_insurance_premium'
# Error processing insurance_premium in ../openfe_experiments/openfe_kaggle_insurance_premium_10k_mcf_2_db_fb_False_grid_search_blend_2_models_v2/kaggle_insurance_premium: [Errno 2] No such file or directory: '../openfe_experiments/openfe_kaggle_insurance_premium_10k_mcf_2_db_fb_False_grid_search_blend_2_models_v2/kaggle_insurance_premium/scores.csv'
#
# Processing insurance_premium in ../openfe_experiments/openfe_kaggle_insurance_premium_10k_mcf_2_db_fb_False_grid_search_blend_3_models_v2/kaggle_insurance_premium'
# Error processing insurance_premium in ../openfe_experiments/openfe_kaggle_insurance_premium_10k_mcf_2_db_fb_False_grid_search_blend_3_models_v2/kaggle_insurance_premium: [Errno 2] No such file or directory: '../openfe_experiments/openfe_kaggle_insurance_premium_10k_mcf_2_db_fb_False_grid_search_blend_3_models_v2/kaggle_insurance_premium/scores.csv'
#
# Processing covertype in ../openfe_experiments/openfe_kaggle_covertype_10k_mcf_2_db_fb_False_grid_search_blend_2_models_v2/kaggle_covertype'
# Error processing covertype in ../openfe_experiments/openfe_kaggle_covertype_10k_mcf_2_db_fb_False_grid_search_blend_2_models_v2/kaggle_covertype: [Errno 2] No such file or directory: '../openfe_experiments/openfe_kaggle_covertype_10k_mcf_2_db_fb_False_grid_search_blend_2_models_v2/kaggle_covertype/scores.csv'
#
# Processing covertype in ../openfe_experiments/openfe_kaggle_covertype_10k_mcf_2_db_fb_False_grid_search_blend_3_models_v2/kaggle_covertype'
# Error processing covertype in ../openfe_experiments/openfe_kaggle_covertype_10k_mcf_2_db_fb_False_grid_search_blend_3_models_v2/kaggle_covertype: [Errno 2] No such file or directory: '../openfe_experiments/openfe_kaggle_covertype_10k_mcf_2_db_fb_False_grid_search_blend_3_models_v2/kaggle_covertype/scores.csv'
#
# Processing loan_loss in ../openfe_experiments/openfe_kaggle_loan_loss_10k_mcf_2_db_fb_False_grid_search_blend_2_models_v2/kaggle_loan_loss'
# Error processing loan_loss in ../openfe_experiments/openfe_kaggle_loan_loss_10k_mcf_2_db_fb_False_grid_search_blend_2_models_v2/kaggle_loan_loss: [Errno 2] No such file or directory: '../openfe_experiments/openfe_kaggle_loan_loss_10k_mcf_2_db_fb_False_grid_search_blend_2_models_v2/kaggle_loan_loss/scores.csv'
#
# Processing loan_loss in ../openfe_experiments/openfe_kaggle_loan_loss_10k_mcf_2_db_fb_False_grid_search_blend_3_models_v2/kaggle_loan_loss'
# Error processing loan_loss in ../openfe_experiments/openfe_kaggle_loan_loss_10k_mcf_2_db_fb_False_grid_search_blend_3_models_v2/kaggle_loan_loss: [Errno 2] No such file or directory: '../openfe_experiments/openfe_kaggle_loan_loss_10k_mcf_2_db_fb_False_grid_search_blend_3_models_v2/kaggle_loan_loss/scores.csv'
